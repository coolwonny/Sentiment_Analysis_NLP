# %% [markdown]
# # Sentiment Analysis

# %%
import os
import pandas as pd
# %matplotlib inline

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %% [markdown]
# # News Headlines Sentiment
#
# Use the news api to pull the latest news articles for bitcoin and ethereum and create a DataFrame of sentiment scores for each coin.
#
# Use descriptive statistics to answer the following questions:
# 1. Which coin had the highest mean positive score?
# 2. Which coin had the highest negative score?
# 3. Which coin had the highest positive score?

# %%
# Read your api key environment variable
from dotenv import load_dotenv
load_dotenv()

load_dotenv('c:/Users/Sungwon Kim/Fintech/.env')
api_key = os.getenv("NEWS_API")

# %%
# Create a newsapi client
from newsapi import NewsApiClient
news_api = NewsApiClient(api_key = api_key)

# %%
# Fetch the Bitcoin news articles
bitcoin_news = news_api.get_everything(q="bitcoin", 
                                          language="en", 
                                          page_size=100,
                                          sort_by="relevancy")

# %%
# Fetch the Ethereum news articles
ethereum_news = news_api.get_everything(q="ethereum", 
                                          language="en", 
                                          page_size=100,
                                          sort_by="relevancy")

# %%
# Create the Bitcoin sentiment scores DataFrame
bitcoin_sentiment = []

for article in bitcoin_news["articles"]:
    try:
        text = article["content"]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        bitcoin_sentiment.append({
            "text": text,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
        })
        
    except AttributeError:
        pass
    
# Create DataFrame
bitcoin_df = pd.DataFrame(bitcoin_sentiment)

# Reorder DataFrame columns
cols = ["compound", "negative", "neutral", "positive", "text",]
bitcoin_df = bitcoin_df[cols]

bitcoin_df.head()
# Out:
#    compound  negative  neutral  positive                                               text
# 0    0.0258     0.059    0.880     0.061  Just hackers burning up 0day like it’s a fire ...
# 1    0.0772     0.000    0.962     0.038  Reuters had previously reported the FBI would ...
# 2    0.0000     0.000    1.000     0.000  Most of these accounts tweeted some variant of...
# 3    0.5994     0.000    0.851     0.149  Our investigation and cooperation with law enf...
# 4    0.1779     0.057    0.866     0.078  The company blacklisted the bitcoin address\r\...

# %%
bitcoin_df["text"]
# Out:
# 0     Just hackers burning up 0day like it’s a fire ...
# 1     Reuters had previously reported the FBI would ...
# 2     Most of these accounts tweeted some variant of...
# 3     Our investigation and cooperation with law enf...
# 4     The company blacklisted the bitcoin address\r\...
# 5     Bitcoin scams are causing a lot of headaches r...
# 6     Much as with Twitter, the YouTube scams use Wo...
# 7     Image copyrightAFP/REUTERSImage caption\r\n Ki...
# 8     A number of high-profile Twitter accounts were...
# 9     A gigantic breach of Twitters security yesterd...
# 10    Image copyrightReuters / AFP\r\nTwitter says h...
# 11    On the back of a major security breach last we...
# 12    Last week’s hack of over 100 very high-profile...
# 13    2020 sure does suck so far. But the year might...
# 14    San Francisco (CNN Business)Twitter(TWTR) acco...
# 15    Something normal happened on Twitter earlier t...
# 16    Twitter spectacularly shit the bed on Wednesda...
# 17    The threat of ransomware may seem ubiquitous, ...
# 18    In case you haven't heard, Barack Obama, Joe B...
# 19    The biggest news on Wednesday was the Twitter ...
# 20    (Reuters) - After several weeks of trading in ...
# 21    (Reuters) - After several weeks of trading in ...
# 22    (Reuters) - After several weeks of trading in ...
# 23    In the days since we saw some of Twitters high...
# 24    WASHINGTON (Reuters) - The official Twitter ac...
# 25    Now that were getting closer to Nvidias antici...
# 26    LONDON/NEW YORK (Reuters) - Hackers who target...
# 27    LONDON/NEW YORK (Reuters) - Hackers who target...
# 28    * Bitcoin wallets used after hack offer invest...
# 29    LONDON (Reuters) - The number of people in Bri...
# 30    A common argument for Bitcoin is that it is no...
# 31    Our robot colleague Satoshi Nakaboto writes ab...
# 32    Our robot colleague Satoshi Nakaboto writes ab...
# 33    Our robot colleague Satoshi Nakaboto writes ab...
# 34    Our robot colleague Satoshi Nakaboto writes ab...
# 35    Our robot colleague Satoshi Nakaboto writes ab...
# 36    Our robot colleague Satoshi Nakaboto writes ab...
# 37    Our robot colleague Satoshi Nakaboto writes ab...
# 38    Our robot colleague Satoshi Nakaboto writes ab...
# 39    Our robot colleague Satoshi Nakaboto writes ab...
# 40    Our robot colleague Satoshi Nakaboto writes ab...
# 41    Our robot colleague Satoshi Nakaboto writes ab...
# 42    Our robot colleague Satoshi Nakaboto writes ab...
# 43    Our robot colleague Satoshi Nakaboto writes ab...
# 44    Posted \r\nThe Twitter accounts of high profil...
# 45    LONDON (Reuters) - Britain’s finance ministry ...
# 46    LONDON (Reuters) - Britain’s finance ministry ...
# 47    Our robot colleague Satoshi Nakaboto writes ab...
# 48    Big money moves hiding in plain sight tend to ...
# 49    Dozens of high-profile Twitter accounts were h...
# 50    SAN FRANCISCO/WASHINGTON (Reuters) - The extra...
# 51    SAN FRANCISCO/WASHINGTON (Reuters) - The extra...
# 52    The story behind Twitter’s massive breach on W...
# 53    Apple, along with a number of high profile Twi...
# 54    The Twitter accounts of some of the most promi...
# 55    Twitter blocked verified users from tweeting i...
# 56    Enlarge/ A screenshot from Wozniak's lawsuit s...
# 57    It looks like the birthplace of Wednesday's gi...
# 58    Don’t send bitcoin to celebrities… or to rando...
# 59    Bitcoin exchange service Coinbase said it bloc...
# 60    TL;DR: A lifetime subscription to StackSkills ...
# 61    Twitter's barn door has been fully, and aggres...
# 62    He also says he has a secret Instagram account...
# 63    WASHINGTON, July 16 (Reuters) - The U.S. Feder...
# 64    Posted \r\nThe Twitter accounts of high profil...
# 65    WASHINGTON (Reuters) - A wave of tweets in app...
# 66    WASHINGTON (Reuters) - The U.S. Federal Bureau...
# 67    According to a public letter from the U.S. Com...
# 68    Twitter lost nearly $1 billion from its market...
# 69    James Martin/CNET\r\nA week after hackers hija...
# 70    The hackers who hijacked dozens of high-profil...
# 71    Elon Musk wants to give you free bitcoin — at ...
# 72    One of the latest bits of Mac malware to keep ...
# 73    If youre waking up just now like me, all of us...
# 74    Whoever hacked Twitter walked away with a lot ...
# 75    SAN FRANCISCO — Con artists on Wednesday appar...
# 76    Twitter confirmed it is investigating the coor...
# 77    Crypto hackers took over the Twitter accounts ...
# 78    Elon Musk's and Bill Gates' Twitter accounts a...
# 79    Its a more bizarre day on Twitter than usual. ...
# 80    Twitter was hit with a massive hack on Wednesd...
# 81    Unverified Twitter accounts had a glorious mom...
# 82    03 July 2020\r\nUnderstanding the fundamental ...
# 83    The bro influencers of TikTok, released into t...
# 84    Twitter has released new details about the hac...
# 85    The Louisiana territory is about four times th...
# 86    In 1998, folk singer Jewel released a book of ...
# 87    A confrontation between venture capitalists an...
# 88    A Twitter hack hits the platform’s most famous...
# 89    The Twitter accounts of several well-known fig...
# 90    The largest Bitcoin wallet that belongs to an ...
# 91    OAKLAND, Calif. Twitter says the hack that com...
# 92    Subscribe to this bi-weekly newsletter here!\r...
# 93    Welcome to 10 Things Before the Opening Bell. ...
# 94    The official Apple Twitter account appears to ...
# 95    Twitter accounts belonging to Tesla CEO Elon M...
# 96    SINGAPORE (Reuters) - Singapore has developed ...
# 97    SINGAPORE, July 13 (Reuters) - Singapore has d...
# 98    MOSCOW, July 22 (Reuters) - Russian lawmakers ...
# 99    The hack hijacked the verified accounts of bol...
# Name: text, dtype: object

# %% [markdown]
# ### Dropping out duplicated texts
#
# This is actually what I found after completing the wordcloud. Some weird name and words were popping up with importance which I thought of trivial. So I had to go back here to see what happened to the texts. Clearly, we can observe specific articles are repeated(31 to 43, and 47). We're going to pull out these from our task. Fortunately, we didn't find any redundancy in the articles of ethereum.

# %%
#  Dropping duplicated texts from the dataframe
bitcoin_df = bitcoin_df.drop(index=bitcoin_df.index[31:44])
bitcoin_df
# Out:
#     compound  negative  neutral  positive                                               text
# 0     0.0258     0.059    0.880     0.061  Just hackers burning up 0day like it’s a fire ...
# 1     0.0772     0.000    0.962     0.038  Reuters had previously reported the FBI would ...
# 2     0.0000     0.000    1.000     0.000  Most of these accounts tweeted some variant of...
# 3     0.5994     0.000    0.851     0.149  Our investigation and cooperation with law enf...
# 4     0.1779     0.057    0.866     0.078  The company blacklisted the bitcoin address\r\...
# 5    -0.8804     0.247    0.753     0.000  Bitcoin scams are causing a lot of headaches r...
# 6    -0.6808     0.153    0.847     0.000  Much as with Twitter, the YouTube scams use Wo...
# 7     0.1280     0.000    0.951     0.049  Image copyrightAFP/REUTERSImage caption\r\n Ki...
# 8    -0.8689     0.277    0.687     0.036  A number of high-profile Twitter accounts were...
# 9    -0.7003     0.191    0.745     0.064  A gigantic breach of Twitters security yesterd...
# 10   -0.3818     0.085    0.915     0.000  Image copyrightReuters / AFP\r\nTwitter says h...
# 11   -0.3182     0.092    0.848     0.060  On the back of a major security breach last we...
# 12   -0.0516     0.044    0.917     0.039  Last week’s hack of over 100 very high-profile...
# 13   -0.5994     0.133    0.817     0.049  2020 sure does suck so far. But the year might...
# 14    0.3182     0.000    0.927     0.073  San Francisco (CNN Business)Twitter(TWTR) acco...
# 15   -0.1531     0.101    0.815     0.084  Something normal happened on Twitter earlier t...
# 16   -0.6908     0.160    0.840     0.000  Twitter spectacularly shit the bed on Wednesda...
# 17   -0.4215     0.112    0.888     0.000  The threat of ransomware may seem ubiquitous, ...
# 18   -0.3182     0.062    0.938     0.000  In case you haven't heard, Barack Obama, Joe B...
# 19    0.0000     0.000    1.000     0.000  The biggest news on Wednesday was the Twitter ...
# 20   -0.4767     0.086    0.914     0.000  (Reuters) - After several weeks of trading in ...
# 21   -0.4767     0.086    0.914     0.000  (Reuters) - After several weeks of trading in ...
# 22   -0.4767     0.086    0.914     0.000  (Reuters) - After several weeks of trading in ...
# 23   -0.5719     0.098    0.902     0.000  In the days since we saw some of Twitters high...
# 24   -0.4019     0.083    0.917     0.000  WASHINGTON (Reuters) - The official Twitter ac...
# 25    0.0000     0.000    1.000     0.000  Now that were getting closer to Nvidias antici...
# 26    0.4019     0.000    0.890     0.110  LONDON/NEW YORK (Reuters) - Hackers who target...
# 27    0.4019     0.000    0.890     0.110  LONDON/NEW YORK (Reuters) - Hackers who target...
# 28    0.0000     0.000    1.000     0.000  * Bitcoin wallets used after hack offer invest...
# 29   -0.4767     0.129    0.797     0.075  LONDON (Reuters) - The number of people in Bri...
# 30   -0.2500     0.120    0.812     0.068  A common argument for Bitcoin is that it is no...
# 44    0.0000     0.000    1.000     0.000  Posted \r\nThe Twitter accounts of high profil...
# 45    0.4404     0.076    0.737     0.187  LONDON (Reuters) - Britain’s finance ministry ...
# 46    0.4404     0.076    0.737     0.187  LONDON (Reuters) - Britain’s finance ministry ...
# 47    0.5070     0.000    0.910     0.090  Our robot colleague Satoshi Nakaboto writes ab...
# 48    0.2023     0.056    0.867     0.077  Big money moves hiding in plain sight tend to ...
# 49   -0.7506     0.186    0.814     0.000  Dozens of high-profile Twitter accounts were h...
# 50    0.0000     0.000    1.000     0.000  SAN FRANCISCO/WASHINGTON (Reuters) - The extra...
# 51    0.0000     0.000    1.000     0.000  SAN FRANCISCO/WASHINGTON (Reuters) - The extra...
# 52   -0.2716     0.060    0.940     0.000  The story behind Twitter’s massive breach on W...
# 53   -0.7717     0.220    0.744     0.036  Apple, along with a number of high profile Twi...
# 54   -0.0276     0.071    0.862     0.068  The Twitter accounts of some of the most promi...
# 55   -0.0516     0.108    0.819     0.073  Twitter blocked verified users from tweeting i...
# 56   -0.6808     0.177    0.823     0.000  Enlarge/ A screenshot from Wozniak's lawsuit s...
# 57    0.2023     0.053    0.870     0.078  It looks like the birthplace of Wednesday's gi...
# 58    0.1027     0.000    0.930     0.070  Don’t send bitcoin to celebrities… or to rando...
# 59   -0.7003     0.158    0.842     0.000  Bitcoin exchange service Coinbase said it bloc...
# 60   -0.6249     0.130    0.870     0.000  TL;DR: A lifetime subscription to StackSkills ...
# 61   -0.8008     0.174    0.826     0.000  Twitter's barn door has been fully, and aggres...
# 62    0.0000     0.000    1.000     0.000  He also says he has a secret Instagram account...
# 63    0.0000     0.000    1.000     0.000  WASHINGTON, July 16 (Reuters) - The U.S. Feder...
# 64    0.0000     0.000    1.000     0.000  Posted \r\nThe Twitter accounts of high profil...
# 65    0.0000     0.000    1.000     0.000  WASHINGTON (Reuters) - A wave of tweets in app...
# 66    0.0000     0.000    1.000     0.000  WASHINGTON (Reuters) - The U.S. Federal Bureau...
# 67    0.5719     0.000    0.868     0.132  According to a public letter from the U.S. Com...
# 68   -0.7650     0.180    0.820     0.000  Twitter lost nearly $1 billion from its market...
# 69    0.0000     0.000    1.000     0.000  James Martin/CNET\r\nA week after hackers hija...
# 70    0.7003     0.000    0.842     0.158  The hackers who hijacked dozens of high-profil...
# 71    0.1526     0.068    0.850     0.082  Elon Musk wants to give you free bitcoin — at ...
# 72   -0.1280     0.118    0.774     0.107  One of the latest bits of Mac malware to keep ...
# 73    0.0772     0.053    0.887     0.060  If youre waking up just now like me, all of us...
# 74   -0.4019     0.076    0.924     0.000  Whoever hacked Twitter walked away with a lot ...
# 75   -0.7506     0.181    0.819     0.000  SAN FRANCISCO — Con artists on Wednesday appar...
# 76    0.5413     0.076    0.760     0.164  Twitter confirmed it is investigating the coor...
# 77    0.7351     0.000    0.816     0.184  Crypto hackers took over the Twitter accounts ...
# 78   -0.7506     0.171    0.829     0.000  Elon Musk's and Bill Gates' Twitter accounts a...
# 79   -0.0754     0.077    0.856     0.068  Its a more bizarre day on Twitter than usual. ...
# 80    0.3612     0.000    0.930     0.070  Twitter was hit with a massive hack on Wednesd...
# 81    0.4767     0.061    0.816     0.122  Unverified Twitter accounts had a glorious mom...
# 82   -0.3612     0.079    0.921     0.000  03 July 2020\r\nUnderstanding the fundamental ...
# 83   -0.2846     0.058    0.942     0.000  The bro influencers of TikTok, released into t...
# 84   -0.5719     0.101    0.899     0.000  Twitter has released new details about the hac...
# 85    0.0000     0.000    1.000     0.000  The Louisiana territory is about four times th...
# 86    0.7531     0.000    0.825     0.175  In 1998, folk singer Jewel released a book of ...
# 87   -0.1280     0.069    0.876     0.054  A confrontation between venture capitalists an...
# 88    0.0000     0.000    1.000     0.000  A Twitter hack hits the platform’s most famous...
# 89    0.0000     0.000    1.000     0.000  The Twitter accounts of several well-known fig...
# 90    0.2263     0.000    0.944     0.056  The largest Bitcoin wallet that belongs to an ...
# 91    0.0000     0.000    1.000     0.000  OAKLAND, Calif. Twitter says the hack that com...
# 92    0.7901     0.000    0.784     0.216  Subscribe to this bi-weekly newsletter here!\r...
# 93    0.4588     0.000    0.925     0.075  Welcome to 10 Things Before the Opening Bell. ...
# 94   -0.0000     0.150    0.678     0.173  The official Apple Twitter account appears to ...
# 95   -0.5859     0.160    0.775     0.065  Twitter accounts belonging to Tesla CEO Elon M...
# 96    0.0000     0.000    1.000     0.000  SINGAPORE (Reuters) - Singapore has developed ...
# 97    0.0000     0.000    1.000     0.000  SINGAPORE, July 13 (Reuters) - Singapore has d...
# 98   -0.7615     0.184    0.783     0.034  MOSCOW, July 22 (Reuters) - Russian lawmakers ...
# 99    0.3612     0.000    0.925     0.075  The hack hijacked the verified accounts of bol...

# %%
# Finally, let's reset the index
bitcoin_df = bitcoin_df.reset_index(drop=True)
bitcoin_df.head()
# Out:
#    compound  negative  neutral  positive                                               text
# 0    0.0258     0.059    0.880     0.061  Just hackers burning up 0day like it’s a fire ...
# 1    0.0772     0.000    0.962     0.038  Reuters had previously reported the FBI would ...
# 2    0.0000     0.000    1.000     0.000  Most of these accounts tweeted some variant of...
# 3    0.5994     0.000    0.851     0.149  Our investigation and cooperation with law enf...
# 4    0.1779     0.057    0.866     0.078  The company blacklisted the bitcoin address\r\...

# %%
# Create the ethereum sentiment scores DataFrame
ethereum_sentiment = []

for article in ethereum_news["articles"]:
    try:
        text = article["content"]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        ethereum_sentiment.append({
            "text" : text,
            "compound" : compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
        })
    except AttributeError:
        pass
    
# Create DataFrame
ethereum_df = pd.DataFrame(ethereum_sentiment)

# Reorder DataFrame columns
ethereum_df = ethereum_df[cols]

ethereum_df.head()
# Out:
#    compound  negative  neutral  positive                                               text
# 0    0.5719     0.000    0.868     0.132  According to a public letter from the U.S. Com...
# 1    0.2263     0.000    0.947     0.053  When the inventor of AWS Lambda, Tim Wagner, a...
# 2   -0.6808     0.177    0.823     0.000  Enlarge/ A screenshot from Wozniak's lawsuit s...
# 3    0.3612     0.051    0.847     0.102  Interest in bitcoin and other cryptocurrencies...
# 4   -0.3400     0.088    0.912     0.000  Lightweight, open-source, universal paper wall...

# %%
# Describe the Bitcoin Sentiment
bitcoin_df.describe()
# Out:
#         compound   negative    neutral   positive
# count  87.000000  87.000000  87.000000  87.000000
# mean   -0.105849   0.067448   0.885701   0.046885
# std     0.433353   0.071002   0.084492   0.058047
# min    -0.880400   0.000000   0.678000   0.000000
# 25%    -0.476700   0.000000   0.821500   0.000000
# 50%     0.000000   0.060000   0.888000   0.034000
# 75%     0.140300   0.110000   0.943000   0.075000
# max     0.790100   0.277000   1.000000   0.216000

# %%
# Describe the Ethereum Sentiment
ethereum_df.describe()
# Out:
#         compound   negative    neutral   positive
# count  97.000000  97.000000  97.000000  97.000000
# mean    0.154446   0.031155   0.905082   0.063773
# std     0.389988   0.047960   0.081059   0.070210
# min    -0.709600   0.000000   0.660000   0.000000
# 25%     0.000000   0.000000   0.847000   0.000000
# 50%     0.000000   0.000000   0.917000   0.060000
# 75%     0.458800   0.058000   1.000000   0.115000
# max     0.859100   0.177000   1.000000   0.280000

# %% [markdown]
# ### Questions:
#
# Q: Which coin had the highest mean positive score?
#
# A: Ethereum did with a mean positive score of 0.064
#
# Q: Which coin had the highest compound score?
#
# A: Ethereum had the highest compound score at 0.859
#
# Q. Which coin had the highest positive score?
#
# A: Again, ethereum had the highest positive score at 0.28.

# %% [markdown]
# ---

# %% [markdown]
# # Tokenizer
#
# In this section, you will use NLTK and Python to tokenize the text for each coin. Be sure to:
# 1. Lowercase each word
# 2. Remove Punctuation
# 3. Remove Stopwords

# %%
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer
from string import punctuation
import re

# %%
# Expand the default stopwords list if necessary
sw = set(stopwords.words('english'))

# %%
# Complete the tokenizer function
def tokenizer(text):
    """Tokenizes text."""
    
    # Remove the punctuation
    regex = re.compile('[^a-zA-z]')
    re_clean = regex.sub(' ', text)
    # Tokenize words    
    words = word_tokenize(re_clean)
     # Lemmatize Words into root words
    lem = [WordNetLemmatizer().lemmatize(word) for word in words]
    # Convert the words to lowercase and remove the stop words
    sw_addon = {'[', ']'}
    tokens = [word.lower() for word in lem if word.lower() not in sw.union(sw_addon)]
    return tokens

# %%
# Create a new tokens column for bitcoin
bitcoin_tokens = [tokenizer(bitcoin_df["text"][i]) for i in range(0, len(bitcoin_df))]
bitcoin_df["tokens"] = bitcoin_tokens
bitcoin_df.head()
# Out:
#    compound  negative  neutral  positive                                               text                                             tokens
# 0    0.0258     0.059    0.880     0.061  Just hackers burning up 0day like it’s a fire ...  [hacker, burning, day, like, fire, sale, imagi...
# 1    0.0772     0.000    0.962     0.038  Reuters had previously reported the FBI would ...  [reuters, previously, reported, fbi, would, la...
# 2    0.0000     0.000    1.000     0.000  Most of these accounts tweeted some variant of...  [account, tweeted, variant, message, someone, ...
# 3    0.5994     0.000    0.851     0.149  Our investigation and cooperation with law enf...  [investigation, cooperation, law, enforcement,...
# 4    0.1779     0.057    0.866     0.078  The company blacklisted the bitcoin address\r\...  [company, blacklisted, bitcoin, address, illus...

# %%
# Create a new tokens column for ethereum
ethereum_tokens = [tokenizer(ethereum_df["text"][i]) for i in range(0, len(ethereum_df))]
ethereum_df["tokens"] = ethereum_tokens
ethereum_df.head()
# Out:
#    compound  negative  neutral  positive                                               text                                             tokens
# 0    0.5719     0.000    0.868     0.132  According to a public letter from the U.S. Com...  [according, public, letter, u, comptroller, cu...
# 1    0.2263     0.000    0.947     0.053  When the inventor of AWS Lambda, Tim Wagner, a...  [inventor, aws, lambda, tim, wagner, former, h...
# 2   -0.6808     0.177    0.823     0.000  Enlarge/ A screenshot from Wozniak's lawsuit s...  [enlarge, screenshot, wozniak, lawsuit, show, ...
# 3    0.3612     0.051    0.847     0.102  Interest in bitcoin and other cryptocurrencies...  [interest, bitcoin, cryptocurrencies, includin...
# 4   -0.3400     0.088    0.912     0.000  Lightweight, open-source, universal paper wall...  [lightweight, open, source, universal, paper, ...

# %% [markdown]
# ---

# %% [markdown]
# # NGrams and Frequency Analysis
#
# In this section you will look at the ngrams and word frequency for each coin.
#
# 1. Use NLTK to produce the n-grams for N = 2.
# 2. List the top 10 words for each coin.

# %%
from collections import Counter
from nltk import ngrams

# %%
# Let's create corpus(or corpora) for the columns containing tokens at each dataframe.
tokens_bitcoin = bitcoin_df["tokens"]
corpus_bitcoin = [' '.join(tokens_bitcoin[i]) for i in range(0, len(bitcoin_df))]

tokens_ethereum = ethereum_df["tokens"]
corpus_ethereum = [' '.join(tokens_ethereum[i]) for i in range(0, len(ethereum_df))]

# %%
# Generate the Bitcoin N-grams where N=2
bigram_bitcoin = [Counter(ngrams(tokens_bitcoin[i], n=2)) for i in range(0, len(bitcoin_df))]
bigram_bitcoin[0]
# Out:
# Counter({('hacker', 'burning'): 1,
#          ('burning', 'day'): 1,
#          ('day', 'like'): 1,
#          ('like', 'fire'): 1,
#          ('fire', 'sale'): 1,
#          ('sale', 'imagine'): 1,
#          ('imagine', 'getting'): 1,
#          ('getting', 'key'): 1,
#          ('key', 'twitter'): 1,
#          ('twitter', 'kingdom'): 1,
#          ('kingdom', 'access'): 1,
#          ('access', 'account'): 1,
#          ('account', 'admin'): 1,
#          ('admin', 'panel'): 1,
#          ('panel', 'world'): 1,
#          ('world', 'would'): 1,
#          ('would', 'could'): 1,
#          ('could', 'grab'): 1,
#          ('grab', 'high'): 1,
#          ('high', 'valu'): 1,
#          ('valu', 'char'): 1})

# %%
# Generate the Ethereum N-grams where N=2
bigram_ethereum = [Counter(ngrams(tokens_ethereum[i], n=2)) for i in range(0, len(ethereum_df))]
bigram_ethereum[0]
# Out:
# Counter({('according', 'public'): 1,
#          ('public', 'letter'): 1,
#          ('letter', 'u'): 1,
#          ('u', 'comptroller'): 1,
#          ('comptroller', 'currency'): 1,
#          ('currency', 'federal'): 1,
#          ('federal', 'group'): 1,
#          ('group', 'responsible'): 1,
#          ('responsible', 'security'): 1,
#          ('security', 'banking'): 1,
#          ('banking', 'system'): 1,
#          ('system', 'bank'): 1,
#          ('bank', 'allowed'): 1,
#          ('allowed', 'hold'): 1,
#          ('hold', 'cryptocurrencies'): 1,
#          ('cryptocurrencies', 'doe'): 1,
#          ('doe', 'char'): 1})

# %%
# Use the token_count function to generate the top 10 words from each coin
def token_count(tokens, N=10):
    """Returns the top N tokens from the frequency count"""
     # Combine all articles in corpus into one large string
    big_string = ' '.join(tokens)
    words = word_tokenize(big_string)
    bigrams = ngrams(words, n=2)
    top_10 = dict(Counter(bigrams).most_common(10))  
    return Counter(top_10).most_common(N)

# %%
# Get the top 10 words for Bitcoin
token_count(corpus_bitcoin)
# Out:
# [(('twitter', 'account'), 21),
#  (('high', 'profile'), 18),
#  (('elon', 'musk'), 16),
#  (('char', 'twitter'), 11),
#  (('bill', 'gates'), 10),
#  (('barack', 'obama'), 10),
#  (('profile', 'account'), 7),
#  (('joe', 'biden'), 7),
#  (('bitcoin', 'scam'), 6),
#  (('profile', 'twitter'), 6)]

# %%
# Get the top 10 words for Ethereum
token_count(corpus_ethereum)
# Out:
# [(('char', 'ethereum'), 10),
#  (('ul', 'li'), 9),
#  (('bitcoin', 'ethereum'), 8),
#  (('char', 'bitcoin'), 6),
#  (('li', 'li'), 6),
#  (('char', 'day'), 5),
#  (('day', 'ahead'), 5),
#  (('ahead', 'ethereum'), 5),
#  (('ethereum', 'would'), 5),
#  (('would', 'need'), 5)]

# %% [markdown]
# # Word Clouds
#
# In this section, you will generate word clouds for each coin to summarize the news for each coin

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = [20.0, 10.0]

# %%
# Generate the Bitcoin word cloud
bitcoin_bigstring = ' '.join(corpus_bitcoin)
input_text_bitcoin = ' '.join(tokenizer(bitcoin_bigstring))
wc = WordCloud().generate(input_text_bitcoin )
plt.imshow(wc)

# %%
# Generate the Ethereum word cloud
ethereum_bigstring = ' '.join(corpus_ethereum)
input_text_ethereum = ' '.join(tokenizer(ethereum_bigstring))
wc = WordCloud().generate(input_text_ethereum)
plt.imshow(wc)

# %% [markdown]
# # Named Entity Recognition
#
# In this section, you will build a named entity recognition model for both coins and visualize the tags using SpaCy.

# %%
import spacy
from spacy import displacy

# %%
# Load the spaCy model
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# ## Bitcoin NER

# %%
# Concatenate all of the bitcoin text together
bitcoin_article = ' '.join(bitcoin_df["text"])

# %%
# Run the NER processor on all of the text
doc = nlp(bitcoin_article)

# %%
# Render the visualization
displacy.render(doc, style='ent')
# Out:
# </br>Imagine getting the keys to the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Twitter
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  kingdom -- access to all the account admin panels in the world. What would you do? You could grab high-valu… [+8860 chars]
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Reuters
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  had previously reported the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     FBI
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>The
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     FBI
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  inquiry is now
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  of multiple investigations into the incident, which has drawn scrutiny from a number o… [+966 chars] Most of these accounts tweeted some variant of the same message: If someone were to send
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  to the address specified in the tweets during a
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     30-minute
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
# </br>Illustration by
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Alex Castro
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br>The cryptocurrency exchange
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Coinbase
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  said that it stopped
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     around 1,100
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  customers from sending bitcoin to hackers who gained a… [+1775 chars]
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  scams are causing a lot of headaches right now. They've gotten so bad that an
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  cofounder has sued
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     YouTube
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
# </br>
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Steve Wozniak
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br>
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     this week
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  against
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     YouTube
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  over… [+3523 chars] Much as with
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Twitter
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , the
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     YouTube
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  scams use
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wozniak
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br> Kim Kardashian West,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Kanye West
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Elon Musk
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bill Gates
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase

# %%
# List all Entities
for ent in doc.ents:
    print(ent.text, ent.label_)
# Out:
# Twitter ORG
# Reuters ORG
# FBI ORG
# FBI ORG
# one CARDINAL
# Bitcoin GPE
# 30-minute TIME
# Alex Castro PERSON
# Coinbase ORG
# around 1,100 CARDINAL
# Bitcoin GPE
# Apple ORG
# YouTube PRODUCT
# Steve Wozniak PERSON
# this week DATE
# YouTube PRODUCT
# Twitter ORG
# YouTube PRODUCT
# Wozniak PERSON
# Kanye West GPE
# Elon Musk ORG
# Bill Gates PERSON
# Barack Obama PERSON
# FBI ORG
# Twitt PERSON
# Twitter PERSON
# Wednesday DATE
# millions CARDINAL
# @rippl ORG
# Twitters ORG
# yesterday DATE
# Bill Gates PERSON
# Barack Obama PERSON
# Appleto PERSON
# Twitter ORG
# earlier this week DATE
# last week DATE
# Twitter ORG
# today DATE
# Last week DATE
# over 100 CARDINAL
# Twitter ORG
# today DATE
# 2020 DATE
# the year DATE
# John McAfee
#   PERSON
# Three years ago DATE
# this date DATE
# July 17, 2017 DATE
# McAfee ORG
# ec ORG
# San Francisco GPE
# CNN ORG
# Joe Biden PERSON
# Bill Gates PERSON
# Elon Musk ORG
# Apple ORG
# Wednesday DATE
# Twitter ORG
# earlier this afternoon TIME
# Elon Musk ORG
# Twitter ORG
# Wednesday evening TIME
# 6 pm ET TIME
# Twitter ORG
# Apple ORG
# Mac ORG
# first ORDINAL
# Mac ORG
# Barack Obama PERSON
# Joe Biden PERSON
# Elon Musk PERSON
# Kanye West GPE
# Apple ORG
# Wednesday DATE
# Twitter ORG
# Barack GPE
# Joe Biden PERSON
# Elon Musk ORG
# Kim Kardashian PERSON
# Reuters ORG
# several weeks DATE
# bitcoin GPE
# 10,000 MONEY
# Sunday DATE
# first ORDINAL
# early June DATE
# Reuters ORG
# several weeks DATE
# bitcoin GPE
# 10,000 MONEY
# Sunday DATE
# first ORDINAL
# early June DATE
# Reuters ORG
# several weeks DATE
# bitcoin GPE
# 10,000 MONEY
# Sunday DATE
# first ORDINAL
# early June DATE
# the days DATE
# Twitters NORP
# WASHINGTON GPE
# Reuters ORG
# Twitter ORG
# Bill Gates PERSON
# Elon Musk ORG
# bitcoin GPE
# Wednesday DATE
# Nvidias GPE
# September 2020 DATE
# GeForce RTX 30 LAW
# Ampere NORP
# LONDON GPE
# Reuters ORG
# Twitter ORG
# 120,000 MONEY
# LONDON GPE
# Reuters ORG
# Twitter ORG
# 120,000 MONEY
# Bitcoin GPE
# Tom Wi PERSON
# LONDON GPE
# Reuters ORG
# Britain GPE
# BTC ORG
# BTSP GPE
# the past year DATE
# Bitcoin GPE
# thousand CARDINAL
# Twitter ORG
# Barack Obama PERSON
# Democratic NORP
# Joe Biden PERSON
# Tesla ORDINAL
# Elon Musk PERSON
# Bill PERSON
# LONDON GPE
# Reuters ORG
# Britain GPE
# Monday DATE
# bitcoin GPE
# LONDON GPE
# Reuters ORG
# Britain GPE
# Monday DATE
# bitcoin GPE
# Satoshi Nakaboto ORG
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Decrypt PERSON
# Bitcoin GPE
# Dozens CARDINAL
# Twitter ORG
# Wednesday DATE
# SAN FRANCISCO GPE
# WASHINGTON GPE
# Reuters ORG
# Twitter ORG
# Wednesday DATE
# SAN FRANCISCO GPE
# WASHINGTON GPE
# Reuters ORG
# Twitter ORG
# Wednesday DATE
# Twitter ORG
# Wednesday DATE
# Friday DATE
# the New York Times ORG
# OGUsers ORG
# Apple ORG
# Twitter ORG
# 9to5Mac CARDINAL
# Twitter ORG
# U.S. GPE
# Barack Obama FAC
# Joe Biden PERSON
# Jeff Bezos PERSON
# Warren Buffett PERSON
# Wednesday DATE
# afternoon TIME
# Twitter PERSON
# Wozniak PERSON
# Bitcoin GPE
# YouTube PRODUCT
# 4 CARDINAL
# 4 CARDINAL
# Apple ORG
# Steve Wozniak PERSON
# YouTube ORG
# Wednesday DATE
# Twitter ORG
# OG WORK_OF_ART
# Original Gangster PERSON
# Twitter ORG
# Wednesday dozens DATE
# This afternoon TIME
# Twitter ORG
# Joe Biden PERSON
# Bill Gates PERSON
# Elon Musk ORG
# Apple ORG
# Bitcoin GPE
# Coinbase ORG
# almost $280,000 MONEY
# Twitter ORG
# last week DATE
# 47.37 MONEY
# July 5 DATE
# 96% PERCENT
# Twitter ORG
# Twitter ORG
# Thursday DATE
# New York Times ORG
# Maureen Dowd PERSON
# Tesla ORDINAL
# Elon Musk ORG
# Twitter ORG
# WASHINGTON GPE
# July 16 DATE
# Reuters ORG
# The U.S. Federal Bureau of Investigation ORG
# Twitter ORG
# two CARDINAL
# Twitter ORG
# Barack Obama PERSON
# Democratic NORP
# Joe Biden PERSON
# Tesla ORDINAL
# Elon Musk PERSON
# Bill PERSON
# WASHINGTON GPE
# Reuters ORG
# Twitter ORG
# Wednesday DATE
# more than half a dozen CARDINAL
# U.S. GPE
# WASHINGTON GPE
# Reuters ORG
# The U.S. Federal Bureau of Investigation ORG
# Twitter ORG
# two CARDINAL
# U.S. GPE
# Twitter ORG
# nearly $1 billion MONEY
# Elon Musk ORG
# Warren Buffet PERSON
# James Martin PERSON
# A week DATE
# Twitter ORG
# US GPE
# Barack Obama PERSON
# Microsoft ORG
# Bill Gates PERSON
# dozens CARDINAL
# Twitter ORG
# this week DATE
# second ORDINAL
# Wednesday DATE
# Elon Musk ORG
# Twitter ORG
# Tesla WORK_OF_ART
# One CARDINAL
# EvilQuest ORG
# Twitters NORP
# Twitter ORG
# San Francisco GPE
# July 15 DATE
# SAN FRANCISCO GPE
# Wednesday DATE
# Twitter ORG
# Twitter ORG
# Twitter ORG
# more than $100,000 MONEY
# Alastair Pi PERSON
# Crypto PERSON
# Twitter ORG
# Bill Gates PERSON
# Kanye West GPE
# Elon Musk ORG
# Barack Obama PERSON
# Elon Musk's ORG
# Bill Gates' PERSON
# Twitter PERSON
# Musk ORG
# Wednesday afternoon TIME
# Twitter ORG
# Twitter ORG
# Obama GPE
# Biden GPE
# Uber GPE
# Apple ORG
# Musk ORG
# Twitter ORG
# Wednesday DATE
# Barack Obama PERSON
# Apple and Uber ORG
# Twitter ORG
# early Wednesday evening TIME
# Twitter PERSON
# 03 CARDINAL
# Bitcoin GPE
# TikTok NORP
# a few years ago DATE
# the Wolves of Social Media ORG
# Twitter ORG
# this week DATE
# bitcoin GPE
# Louisiana GPE
# about four CARDINAL
# France GPE
# Spain GPE
# Mississippi LOC
# the western territories LOC
# 1998 DATE
# Jewel PERSON
# A Night Without Armor WORK_OF_ART
# Twitter ORG
# ul><li PERSON
# Twitter ORG
# Netflix PERSON
# Revel PERSON
# San Francisco GPE
# Daily Crunch WORK_OF_ART
# July 16, 2020 DATE
# Tw PERSON
# Twitter ORG
# Bitcoin GPE
# Bitcoin GPE
# 101,857 CARDINAL
# BTC ORG
# just over $933 million MONEY
# OAKLAND GPE
# Twitter ORG
# 130 CARDINAL
# 45 CARDINAL
# Pardon The Intrusion ORG
# TNWs bi-weekly PERSON
# Bitcoin GPE
# 10 CARDINAL
# the Opening Bell ORG
# every morning TIME
# 1 CARDINAL
# Twitter ORG
# Apple Twitter ORG
# Twitter ORG
# Tesla ORDINAL
# Elon Musk ORG
# Microsoft ORG
# Bill Gates PERSON
# Apple ORG
# Uber ORG
# Bitcoin.org ORG
# Wednesday DATE
# Bitcoin GPE
# SINGAPORE PERSON
# Reuters ORG
# Singapore GPE
# Monday DATE
# SINGAPORE GPE
# July 13 DATE
# Reuters ORG
# Singapore GPE
# Monday DATE
# July 22 DATE
# Reuters ORG
# Russian NORP
# Wednesday DATE
# Elon Musk ORG
# Tesla Inc. ORG
# TSLA ORG
# -2.93% PERCENT
# Bill Gates PERSON
# Microsoft ORG
# -1.98% PERCENT
# Jeff Bezos PERSON

# %% [markdown]
# ---

# %% [markdown]
# ## Ethereum NER

# %%
# Concatenate all of the bitcoin text together
ethereum_article = ' '.join(ethereum_df["text"])

# %%
# Run the NER processor on all of the text
doc = nlp(ethereum_article)

# %%
# Render the visualization
displacy.render(doc, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">According to a public letter from the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     U.S.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# </br>This doe… [+1760 chars] When the inventor of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AWS Lambda
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tim Wagner
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , and the former head of blockchain at AWS,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Shruthi Rao
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , co-found a startup, it’s probably worth paying attention.
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Vendia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , as the new venture is called, com… [+4751 chars]
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Enlarge/
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  A screenshot from
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wozniak
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# 's lawsuit shows a typical &quot;
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  giveaway&quot; scam video on
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     YouTube
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
# </br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     4
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  with
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     4
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# </br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  co-founder
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Steve Wozniak
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  has sued
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     YouTube
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>Using
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     third
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
# </br>Every computer operating system needs a killer app. Without an application that grabs the imagination of the early adopters, a piece of technology will languish. The PC had
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     WordStar
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
# , the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>Ive never been a fan of Ethereum because … [+4415 chars] Many who are new to crypto assume that there will only be
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# </br>Why? Because differe… [+9664 chars]
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     BITCOIN DASH THE Bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  is the original cryptocurrency, and was released as open-source software in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2009
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# .
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CRYPTO UNIVERSE Dash
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  is an attempt to improve on
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.

# %%
# List all Entities
for ent in doc.ents:
    print(ent.text, ent.label_)
# Out:
# U.S. GPE
# AWS Lambda ORG
# Tim Wagner PERSON
# Shruthi Rao PERSON
# Vendia ORG
# Enlarge/ CARDINAL
# Wozniak PERSON
# Bitcoin GPE
# YouTube PRODUCT
# 4 CARDINAL
# 4 CARDINAL
# Apple ORG
# Steve Wozniak PERSON
# YouTube ORG
# third ORDINAL
# WordStar PRODUCT
# Apple ORG
# one CARDINAL
# BITCOIN DASH THE Bitcoin ORG
# 2009 DATE
# CRYPTO UNIVERSE Dash PERSON
# Bitcoin GPE
# two CARDINAL
# Bitcoin GPE
# Ethereum GPE
# ERC20 ORG
# The Ledger Nano X Bluetooth WORK_OF_ART
# 89.25 MONEY
# Amazon ORG
# Sigal Mandelker PERSON
# U.S. Treasury ORG
# 2018 DATE
# the Department of Justice ORG
# Bitcoin GPE
# a weird year DATE
# year DATE
# second ORDINAL
# Bitcoin GPE
# 10,000 MONEY
# 2.0 CARDINAL
# Wednesday DATE
# end-of-year DATE
# August 4 DATE
# Medalla PERSON
# DisclosureThe ORG
# CoinDesk PRODUCT
# the last day DATE
# Devcon ORG
# October 2019 DATE
# Osaka GPE
# Japan GPE
# roughly 1,000 CARDINAL
# Nearly $60 million MONEY
# June DATE
# Dune Analytics ORG
# Bitcoin GPE
# Takeaway PERSON
# ul><li PERSON
# One CARDINAL
# Bitcoin GPE
# Litecoin GPE
# Only 30% PERCENT
# Ethereum Classics ORG
# last week DATE
# OpenEthereum ORG
# Ethereum Classic PRODUCT
# DisclosureThe ORG
# CoinDesk PRODUCT
# Travel Rule WORK_OF_ART
# Satoshi PERSON
# one CARDINAL
# Ethereum Classic FAC
# The Takeaway:
#  WORK_OF_ART
# Blocknative ORG
# zero CARDINAL
# Mempools PERSON
# Camila Russo PERSON
# The Infinite Machine WORK_OF_ART
# first ORDINAL
# today DATE
# Almost five years ago DATE
# July DATE
# DeFi LOC
# Indias Supreme Court ORG
# March DATE
# Binance ORG
# the Internet and Mobile Association of India ORG
# Los Angeles GPE
# Generation Z’s ORG
# DeFi FAC
# DeFi ORG
# 2.0 client MONEY
# Richard Ma PERSON
# Quantstamp GPE
# CoinDesk PERSON
# Twitter ORG
# Bitcoin GPE
# Russia GPE
# ConsenSys ORG
# Night Takeoff Of The American Space Shuttle WORK_OF_ART
# recent weeks DATE
# BTC ORG
# CoinDesk’s Markets Daily ORG
# Bitcoin GPE
# Marlin PRODUCT
# OpenWeaver PRODUCT
# San Francisco GPE
# U.S. GPE
# Bangalore GPE
# India GPE
# Eth 2.0 PERSON
# 2020 DATE
# Twitter ORG
# Hong Kong GPE
# Blockchain Bites ORG
# daily DATE
# bl PERSON
# Sorare PRODUCT
# today DATE
# $4 million MONEY
# Coindesk PERSON
# two-year DATE
# DeFi ORG
# Coin Metrics ORG
# ul><li PERSON
# Coin Metrics' ORG
# over 60% PERCENT
# a month DATE
# Sparkpool GPE
# daily DATE
# crypto GPE
# bitcoin GPE
# R3 Corda GPE
# Italy GPE
# Geth PERSON
# Ethereum Core ORG
# DisclosureThe ORG
# CoinDesk PRODUCT
# Lex Sokolin PERSON
# Global Fintech PERSON
# ConsenSys ORG
# Brooklyn GPE
# Fintech Blueprint ORG
# Enterprise Ethereum Alliance ORG
# EEA ORG
# second ORDINAL
# Daniel C. Burnett PERSON
# Burnett PERSON
# U.K. GPE
# Blockchain Bites GPE
# Latin America LOC
# three CARDINAL
# EOS ORG
# 2018 DATE
# Five years ago DATE
# Ethereum GPE
# app ORG
# Mac ORG
# Orchid VPN PRODUCT
# Wednesday DATE
# Ethereum 2.0 ORG
# The Ethereum Foundation ORG
# BSC ORG
# Chainlink ORG
# Thursday DATE
# June 30 DATE
# the U.S. Senate Banking Committee ORG
# U.S. GPE
# ul><li PERSON
# weekly DATE
# This week DATE
# 4 CARDINAL
# two years DATE
# one metric QUANTITY
# seven-day DATE
# 405,014 CARDINAL
# Friday DATE
# this year DATE
# early 2018 DATE
# Bitcoin GPE
# Ethereum GPE
# June DATE
# ul><li PERSON
# Bitcoin GPE
# BTC ORG
# around $9,184 MONEY
# 20:30 TIME
# 4:30 p.m. EDT TIME
# 0.20% PERCENT
# 24 hours.</li QUANTITY
# the U.S. Securities and Exchange Commission ORG
# SEC ORG
# Ibrahim Alkurd PERSON
# New Mine GPE
# Lavaliere Capital ORG
# Bitcoin GPE
# Bitcoin GPE
# 2.14% PERCENT
# Tuesday DATE
# Mondays DATE
# 8.56% PERCENT
# the day DATE
# 2.5605 MONEY
# the day DATE
# early morning TIME
# 2.6308 MONEY
# Sorare PRODUCT
# $4 million MONEY
# German NORP
# Andre Schurrle PERSON
# Tether PERSON
# 39 CARDINAL
# USDT ORG
# Philippe Castonguay PERSON
# Horizon Games ORG
# Dune ORG
# OSS ORG
# Dev Dev PERSON
# The Big Short FAC
# The History of the Future WORK_OF_ART
# The Spider Network ORG
# second ORDINAL
# Tether PERSON
# one CARDINAL
# first ORDINAL
# fiat ORG
# July 2014 DATE
# Tether PERSON
# Realcoin ORG
# 1.00 MONEY
# British NORP
# Revolut ORG
# New York GPE
# Paxos ORG
# Bitcoin GPE
# US GPE
# the United States GPE
# March this year DATE
# Revol PERSON
# over 60% PERCENT
# a month DATE
# Sparkpool GPE
# daily DATE
# DEFI ORG
# bitcoin GPE
# Camila Russo’s PERSON
# The Infinite Machine WORK_OF_ART
# July 14 DATE
# July 22 DATE
# midnight TIME
# Switzerland GPE
# Graph GPE
# $5 million MONEY
# Framework Ventures ORG
# Coinbase Ventures ORG
# Digital Currency Group ORG
# Multicoin Capital ORG
# DTC Capital ORG
# 6.01% PERCENT
# Saturday DATE
# 0.06% PERCENT
# Friday DATE
# EOS ORG
# the day DATE
# 2.3332 MONEY
# the day DATE
# early morning TIME
# 2.4642 MONEY
# the start of 2021 DATE
# Justin Drake PERSON
# Reddi GPE
# CRYPTOKNOWMICS Union Sobtract Intersect Difference ORG
# 72% PERCENT
# 1,200 CARDINAL
# 1,300 CARDINAL
# 1,000 CARDINAL
# Bitcoin GPE
# Twitter ORG
# Joe Biden PERSON
# Elon Musk ORG
# Apple ORG
# Wednesday DATE
# Twitter ORG
# Twitter ORG
# 9,000 MONEY
# ul><li PERSON
# Bitcoin GPE
# BTC ORG
# around $9,109 MONEY
# 20:00 TIME
# 4 p.m. ET TIME
# 0.66% PERCENT
# the previous 24 hours TIME
# Takeaway PERSON
# ul><li PERSON
# China GPE
# Blockchain GPE
# Service Network ORG
# BSN ORG
# six CARDINAL
# Tezos LOC
# NEO ORG
# Nervos ORG
# EOS ORG
# Australian NORP
# ICO ORG
# Coinsquare PRODUCT
# South Kor PERSON
# New York State GPE
# Bitfinex PERSON
# Latin America LOC
# Gavin Wood PERSON
# the Ethereum Foundation ORG
# 2016 DATE
# the day ahead DATE
# 222.50 MONEY
# first ORDINAL
# 229.52 MONEY
# Token ORG
# Elon Musk's ORG
# second ORDINAL
# Udemy GPE
# the day ahead DATE
# 223.35 MONEY
# first ORDINAL
# 229.34 MONEY
# Australian NORP
# ICO ORG
# Coinsquare PRODUCT
# South Kor PERSON
# Takeaway ORG
# ul><li PERSON
# Blocknative ORG
# zero CARDINAL
# Black Thursday EVENT
# Mempools PERSON
# Monthly DATE
# Bitcoin GPE
# June DATE
# late 2019 DATE
# early 2020 DATE
# monthly DATE
# this summer DATE
# first ORDINAL
# more than $50,000 MONEY
# two days DATE
# ul><li PERSON
# Indias Supreme Court ORG
# March DATE
# Binance ORG
# the Internet and Mobile Association of India ORG
# Latin America LOC
# three CARDINAL
# EOS ORG
# 2018 DATE
# two-year DATE
# DeFi ORG
# Coin ORG
# Coin Metrics' ORG
# Grayscale Investments ORG
# Bitcoin Cash Trust ORG
# Litecoin Trust ORG
# march DATE
# Chinese NORP
# Uber ORG
# digital yuan ORG
# Ethereum alliance ORG
# DeFi PERSON
# Chainlink ORG
# the day ahead DATE
# $239.3 pivot MONEY
# first ORDINAL
# 243.94 MONEY
# the day ahead DATE
# 239.60 MONEY
# first ORDINAL
# 243.69 MONEY
# the day ahead DATE
# 244.70pivot MONEY
# first ORDINAL
# 251.46 MONEY
# Tesla ORDINAL
# SpaceX CARDINAL
# Elon Musk ORG
# second ORDINAL
# Bitcoin GPE
# Ethereum GPE
# June DATE
